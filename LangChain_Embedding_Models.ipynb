# %% [markdown]
# <a href="https://colab.research.google.com/github/rahul02500/Practicepython/blob/main/M4_L2_LangChain_Embedding_Models.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Exploring Embedding Models in LangChain

# %% [markdown]
# ## Install OpenAI, HuggingFace and LangChain dependencies

# %%
# !pip install langchain==0.3.26
# !pip install langchain-openai==0.3.27
# !pip install langchain-community==0.3.27
# !pip install langchain-huggingface==0.3.0
# Out:
# Collecting langchain==0.3.26
#   Downloading langchain-0.3.26-py3-none-any.whl.metadata (7.8 kB)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.26) (0.3.83)
# Collecting langchain-text-splitters<1.0.0,>=0.3.8 (from langchain==0.3.26)
#   Downloading langchain_text_splitters-0.3.11-py3-none-any.whl.metadata (1.8 kB)
# Requirement already satisfied: langsmith>=0.1.17 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.26) (0.7.3)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.26) (2.12.3)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.26) (2.0.46)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.26) (2.32.4)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.12/dist-packages (from langchain==0.3.26) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain==0.3.26) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain==0.3.26) (1.33)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain==0.3.26) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain==0.3.26) (25.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain==0.3.26) (0.14.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.26) (0.28.1)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.26) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.26) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.26) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith>=0.1.17->langchain==0.3.26) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.26) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.26) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain==0.3.26) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.26) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.26) (3.11)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.26) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.12/dist-packages (from requests<3,>=2->langchain==0.3.26) (2026.1.4)
# Requirement already satisfied: greenlet>=1 in /usr/local/lib/python3.12/dist-packages (from SQLAlchemy<3,>=1.4->langchain==0.3.26) (3.3.1)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.26) (4.12.1)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.26) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith>=0.1.17->langchain==0.3.26) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.66->langchain==0.3.26) (3.0.0)
# Downloading langchain-0.3.26-py3-none-any.whl (1.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 39.2 MB/s eta 0:00:00
# Downloading langchain_text_splitters-0.3.11-py3-none-any.whl (33 kB)
# Installing collected packages: langchain-text-splitters, langchain
#   Attempting uninstall: langchain
#     Found existing installation: langchain 1.2.10
#     Uninstalling langchain-1.2.10:
#       Successfully uninstalled langchain-1.2.10
# Successfully installed langchain-0.3.26 langchain-text-splitters-0.3.11
# Requirement already satisfied: langchain-openai==0.3.27 in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.12/dist-packages (from langchain-openai==0.3.27) (0.3.83)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai==0.3.27) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-openai==0.3.27) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.7.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (2.12.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.27) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.27) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.3.27) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.3.27) (2.5.0)
# Traceback (most recent call last):
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/base_command.py", line 179, in exc_logging_wrapper
#     status = run_func(*args)
#              ^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/cli/req_command.py", line 67, in wrapper
#     return func(self, options, args)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/pip/_internal/commands/install.py", line 447, in run
# ^C

# %% [markdown]
# ## Enter Open AI and HuggingFace API Tokens

# %%
from getpass import getpass

OPENAI_KEY = getpass('Enter Open AI API Key: ')
# Out:
# Enter Open AI API Key: ··········

# %%
from getpass import getpass

HUGGINGFACEHUB_API_TOKEN = getpass('Enter HuggingFace Auth Token Key: ')
# Out:
# Enter HuggingFace Auth Token Key: ··········

# %% [markdown]
# ## Setup Environment Variables

# %%
import os

os.environ['OPENAI_API_KEY'] = OPENAI_KEY
os.environ['HUGGINGFACEHUB_API_TOKEN'] = HUGGINGFACEHUB_API_TOKEN

# %% [markdown]
# ## Embedding models
#
# The Embeddings class is a class designed for interfacing with text embedding models. There are lots of embedding model providers (OpenAI, Cohere, Hugging Face, etc) - this class is designed to provide a standard interface for all of them.
#
# Embeddings create a vector representation of a piece of text. This is useful because it means we can think about text in the vector space, and do things like semantic search where we look for pieces of text that are most similar in the vector space.
#
# The base Embeddings class in LangChain provides two methods: one for embedding documents and one for embedding a query. The former takes as input multiple texts, while the latter takes a single text. The reason for having these as two separate methods is that some embedding providers have different embedding methods for documents (to be searched over) vs queries (the search query itself).

# %%
docs = [
    "cats eat and sleep",
    "dogs eat and bark",
    "cars drive fast",
    "vehicles include trucks and cars"
]

# %% [markdown]
# Embeddings create a vector representation of a piece of text. This is useful because it means we can think about text in the vector space, and do things like semantic search where we look for pieces of text that are most similar in the vector space.
#
# The base Embeddings class in LangChain provides two methods: one for embedding documents and one for embedding a query. The former, `.embed_documents`, takes as input multiple texts, while the latter, `.embed_query`, takes a single text. The reason for having these as two separate methods is that some embedding providers have different embedding methods for documents (to be searched over) vs queries (the search query itself).
#
# - `.embed_query`  will return a list of floats,
# - `.embed_documents` returns a list of lists of floats.

# %% [markdown]
# ### Open AI Embedding Models
#
# LangChain enables us to access Open AI embedding models which include the newest models: a smaller and highly efficient `text-embedding-3-small` model, and a larger and more powerful `text-embedding-3-large` model.

# %%
pip install langchain-openai==0.3.27
# Out:
# Requirement already satisfied: langchain-openai==0.3.27 in /usr/local/lib/python3.12/dist-packages (0.3.27)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.66 in /usr/local/lib/python3.12/dist-packages (from langchain-openai==0.3.27) (0.3.83)
# Requirement already satisfied: openai<2.0.0,>=1.86.0 in /usr/local/lib/python3.12/dist-packages (from langchain-openai==0.3.27) (1.109.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.12/dist-packages (from langchain-openai==0.3.27) (0.12.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.7.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (1.33)
# Requirement already satisfied: PyYAML<7.0.0,>=5.3.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (6.0.3)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (4.15.0)
# Requirement already satisfied: packaging<26.0.0,>=23.2.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (25.0)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (2.12.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.14.0)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (4.12.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (1.9.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (0.28.1)
# Requirement already satisfied: jiter<1,>=0.4.0 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (0.13.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.12/dist-packages (from openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (4.67.3)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.27) (2025.11.3)
# Requirement already satisfied: requests>=2.26.0 in /usr/local/lib/python3.12/dist-packages (from tiktoken<1,>=0.7->langchain-openai==0.3.27) (2.32.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.12/dist-packages (from anyio<5,>=3.5.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (3.11)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai<2.0.0,>=1.86.0->langchain-openai==0.3.27) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (1.0.0)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.66->langchain-openai==0.3.27) (0.4.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.3.27) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.26.0->tiktoken<1,>=0.7->langchain-openai==0.3.27) (2.5.0)

# %%
from langchain_openai import OpenAIEmbeddings

# details here: https://openai.com/blog/new-embedding-models-and-api-updates
openai_embed_model = OpenAIEmbeddings(model='text-embedding-3-small')

# %%
embeddings = openai_embed_model.embed_documents(docs)

# %%
len(embeddings)
# Out:
# 4

# %%
len(embeddings[0])
# Out:
# 1536

# %%
print(embeddings[0])
# Out:
# [-0.014177093282341957, -0.004976172931492329, -0.009036445990204811, 0.01158419530838728, 0.020240090787410736, 0.026702988892793655, 0.023839188739657402, 0.035087984055280685, -0.0050664725713431835, 0.0032314485870301723, 0.05015517771244049, 0.0012254994362592697, 0.03108898550271988, 0.046955980360507965, 0.0034668734297156334, 0.01676999218761921, 0.008081846870481968, 0.012242094613611698, -0.006998247001320124, 0.03550078347325325, 0.0372035838663578, -0.02899918705224991, 0.03212098404765129, -0.03583618253469467, -0.029721586033701897, 0.054747574031353, -0.00852044578641653, 0.03351418673992157, 0.012125995010137558, -0.029308786615729332, 0.02483248896896839, -0.040686581283807755, -0.01138424500823021, -0.04086718335747719, 0.011397144757211208, 0.023078089579939842, 0.020214291289448738, -0.031475987285375595, -0.0067724972032010555, 0.013286993838846684, -0.009333145804703236, 0.01478339359164238, 0.021813889965415, -0.009494395926594734, -0.009068695828318596, -0.022497590631246567, -0.029050787910819054, -0.0066499472595751286, 0.05448957532644272, 0.02174939028918743, -0.0013940056087449193, -0.023245789110660553, 0.002757373731583357, -0.02141399122774601, -0.0025880613829940557, 0.012932244688272476, 0.024316489696502686, 0.028457388281822205, -0.00443437322974205, 0.008855845779180527, 0.011577744968235493, 0.056295573711395264, 0.07048556953668594, -0.0035700735170394182, 0.0026267613284289837, 0.005559897515922785, 0.02217509038746357, -0.040428582578897476, -0.014241593889892101, -0.028096187859773636, -0.01372559368610382, -0.010571544989943504, -0.0241358894854784, 0.055211976170539856, 0.04909737780690193, 0.010107145644724369, -0.01989179104566574, 0.004847172647714615, 0.03965458273887634, 0.07631636410951614, -0.00423442292958498, 0.040557581931352615, 0.02287168987095356, -0.027863986790180206, -0.01079084537923336, -0.03867418318986893, -0.024522889405488968, -0.016202392056584358, -0.00680474704131484, 0.028225187212228775, 0.04711077734827995, -0.013106394559144974, -0.05830797553062439, -0.020639991387724876, 0.018717892467975616, 0.0177374929189682, -0.011164944618940353, -0.02576128952205181, 0.010184545069932938, 0.0058791725896298885, 0.03039238601922989, -0.029721586033701897, -0.021891290321946144, 0.015854092314839363, 0.00765614677220583, 0.01922099106013775, 0.01885979250073433, -0.027786588296294212, 0.030056986957788467, -0.01297739427536726, -0.02251048944890499, -0.04401478171348572, 0.005085822660475969, -0.015041393227875233, -0.00584369758144021, -0.024290690198540688, 0.04922637715935707, -0.0027025488670915365, -0.02462608925998211, -0.010848895646631718, 0.052993178367614746, 0.07043396681547165, -0.031114786863327026, -0.043111782521009445, -0.02392948977649212, -0.013164443895220757, -0.008778446353971958, -0.025374289602041245, -0.04447918012738228, 0.011364894919097424, -0.011539044789969921, 0.010494145564734936, 0.042182981967926025, -0.04269897937774658, -0.02625148929655552, 0.007681946735829115, -0.028689587488770485, 0.005301897879689932, -0.042647380381822586, 0.05433477461338043, 0.03841618448495865, -0.027141587808728218, -0.004656897857785225, 0.025967689231038094, -0.024084288626909256, -0.03882898390293121, 0.01531229354441166, 0.040918782353401184, -0.030211785808205605, -0.057327575981616974, -0.011429394595324993, 0.034623585641384125, -0.02783818729221821, 0.028844386339187622, -0.03157918527722359, 0.036016784608364105, 0.04641417786478996, -0.058720774948596954, -0.021568790078163147, 0.03542338311672211, 0.03599098324775696, -0.058359574526548386, 0.013261194340884686, 0.027863986790180206, -0.025051789358258247, 0.01286129467189312, -0.03849358484148979, 0.023090990260243416, -0.0337463840842247, -0.017595592886209488, -0.004476298112422228, -0.030547186732292175, -0.028612187132239342, -0.02608378790318966, -0.010765044949948788, -0.0088816462084651, 0.005611497443169355, 0.027760786935687065, -0.02101409062743187, -0.013712693937122822, 0.02472928 ...

# %%
docs
# Out:
# ['cats eat and sleep',
#  'dogs eat and bark',
#  'cars drive fast',
#  'vehicles include trucks and cars']

# %%
from sklearn.metrics.pairwise import cosine_similarity

sim_matrix = cosine_similarity(embeddings)
sim_matrix
# Out:
# array([[1.        , 0.6126697 , 0.20352739, 0.19823333],
#        [0.6126697 , 1.        , 0.26190051, 0.2003429 ],
#        [0.20352739, 0.26190051, 1.        , 0.39909568],
#        [0.19823333, 0.2003429 , 0.39909568, 1.        ]])

# %%
pip install langchain-huggingface==0.3.0
# Out:
# Collecting langchain-huggingface==0.3.0
#   Downloading langchain_huggingface-0.3.0-py3-none-any.whl.metadata (996 bytes)
# Requirement already satisfied: langchain-core<1.0.0,>=0.3.65 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface==0.3.0) (0.3.83)
# Requirement already satisfied: tokenizers>=0.19.1 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface==0.3.0) (0.22.2)
# Requirement already satisfied: huggingface-hub>=0.30.2 in /usr/local/lib/python3.12/dist-packages (from langchain-huggingface==0.3.0) (1.4.1)
# Requirement already satisfied: filelock in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (3.24.2)
# Requirement already satisfied: fsspec>=2023.5.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.2.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (1.2.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (0.28.1)
# Requirement already satisfied: packaging>=20.9 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (25.0)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (6.0.3)
# Requirement already satisfied: shellingham in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (1.5.4)
# Requirement already satisfied: tqdm>=4.42.1 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (4.67.3)
# Requirement already satisfied: typer-slim in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (0.24.0)
# Requirement already satisfied: typing-extensions>=4.1.0 in /usr/local/lib/python3.12/dist-packages (from huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (4.15.0)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (0.7.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (9.1.4)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (1.33)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (2.12.3)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in /usr/local/lib/python3.12/dist-packages (from langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (0.14.0)
# Requirement already satisfied: anyio in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (4.12.1)
# Requirement already satisfied: certifi in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (2026.1.4)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (1.0.9)
# Requirement already satisfied: idna in /usr/local/lib/python3.12/dist-packages (from httpx<1,>=0.23.0->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (3.11)
# Requirement already satisfied: h11>=0.16 in /usr/local/lib/python3.12/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (0.16.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.12/dist-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (3.0.0)
# Requirement already satisfied: orjson>=3.9.14 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (3.11.7)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (2.32.4)
# Requirement already satisfied: xxhash>=3.0.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (3.6.0)
# Requirement already satisfied: zstandard>=0.23.0 in /usr/local/lib/python3.12/dist-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (0.25.0)
# Requirement already satisfied: annotated-types>=0.6.0 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in /usr/local/lib/python3.12/dist-packages (from pydantic<3.0.0,>=2.7.4->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (0.4.2)
# Requirement already satisfied: typer>=0.24.0 in /usr/local/lib/python3.12/dist-packages (from typer-slim->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (0.24.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (3.4.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.12/dist-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<1.0.0,>=0.3.65->langchain-huggingface==0.3.0) (2.5.0)
# Requirement already satisfied: click>=8.2.1 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (8.3.1)
# Requirement already satisfied: rich>=12.3.0 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (13.9.4)
# Requirement already satisfied: annotated-doc>=0.0.2 in /usr/local/lib/python3.12/dist-packages (from typer>=0.24.0->typer-slim->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (0.0.4)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (4.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /usr/local/lib/python3.12/dist-packages (from rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (2.19.2)
# Requirement already satisfied: mdurl~=0.1 in /usr/local/lib/python3.12/dist-packages (from markdown-it-py>=2.2.0->rich>=12.3.0->typer>=0.24.0->typer-slim->huggingface-hub>=0.30.2->langchain-huggingface==0.3.0) (0.1.2)
# Downloading langchain_huggingface-0.3.0-py3-none-any.whl (27 kB)
# Installing collected packages: langchain-huggingface
# Successfully installed langchain-huggingface-0.3.0

# %%
from langchain_huggingface import HuggingFaceEmbeddings

# check out model details here: https://huggingface.co/mixedbread-ai/mxbai-embed-large-v1
model_name = "mixedbread-ai/mxbai-embed-large-v1"

hf_embeddings = HuggingFaceEmbeddings(
    model_name=model_name,
)
# Out:
# /usr/local/lib/python3.12/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# WARNING:huggingface_hub.utils._http:Warning: You are sending unauthenticated requests to the HF Hub. Please set a HF_TOKEN to enable higher rate limits and faster downloads.
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/266 [00:00<?, ?B/s]
# README.md: 0.00B [00:00, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/677 [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/670M [00:00<?, ?B/s]
# Loading weights:   0%|          | 0/391 [00:00<?, ?it/s]
# tokenizer_config.json: 0.00B [00:00, ?B/s]
# vocab.txt: 0.00B [00:00, ?B/s]
# tokenizer.json: 0.00B [00:00, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/695 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/297 [00:00<?, ?B/s]

# %% [markdown]
# ## Open Source Embedding Models on HuggingFace
#
# `langchain-huggingface` integrates seamlessly with LangChain, providing an efficient and effective way to utilize Hugging Face models within the LangChain ecosystem.
#
# `HuggingFaceEmbeddings`uses `sentence-transformers` embeddings. It computes the embedding locally, using your computer resources and allows you to access open or open source embedding LLMs hosted on HuggingFace.

# %%
embeddings = hf_embeddings.embed_documents(docs)

# %%
len(embeddings)
# Out:
# 4

# %%
len(embeddings[0])
# Out:
# 1024

# %%
docs
# Out:
# ['cats eat and sleep',
#  'dogs eat and bark',
#  'cars drive fast',
#  'vehicles include trucks and cars']

# %%
sim_matrix = cosine_similarity(embeddings)
sim_matrix
# Out:
# array([[1.        , 0.52524247, 0.34210254, 0.3368122 ],
#        [0.52524247, 1.        , 0.31724103, 0.3307099 ],
#        [0.34210254, 0.31724103, 1.        , 0.72249998],
#        [0.3368122 , 0.3307099 , 0.72249998, 1.        ]])

# %% [markdown]
# ## Build a small search engine!

# %% [markdown]
# ### Load Knowledgebase documents

# %%
documents = [
    'Quantum mechanics describes the behavior of very small particles.',
    'Photosynthesis is the process by which green plants make food using sunlight.',
    "Shakespeare's plays are a testament to English literature.",
    'Artificial Intelligence aims to create machines that can think and learn.',
    'The pyramids of Egypt are historical monuments that have stood for thousands of years.',
    'Biology is the study of living organisms and their interactions with the environment.',
    'Music therapy can aid in the mental well-being of individuals.',
    'The Milky Way is just one of billions of galaxies in the universe.',
    'Economic theories help understand the distribution of resources in society.',
    'Yoga is an ancient practice that involves physical postures and meditation.'
]

# %%
len(documents)
# Out:
# 10

# %% [markdown]
# ### Get document embeddings

# %%
document_embeddings = openai_embed_model.embed_documents(documents)

# %% [markdown]
# ### Let's try to find the most similar document for one query

# %%
new_text = 'What is AI?'
new_text
# Out:
# 'What is AI?'

# %%
query_embedding = openai_embed_model.embed_query(new_text)

# %%
cosine_similarities = cosine_similarity([query_embedding], document_embeddings)
cosine_similarities
# Out:
# array([[ 0.10212454,  0.09252234, -0.00534622,  0.6313588 ,  0.02336383,
#          0.09317177,  0.10769226,  0.07003597,  0.05820366,  0.06606796]])

# %%
import numpy as np

documents[np.argmax(cosine_similarities[0])]
# Out:
# 'Artificial Intelligence aims to create machines that can think and learn.'

# %% [markdown]
# ### Create Search Engine function

# %%
def semantic_search_engine(query, embedder_model):
  query_embedding = embedder_model.embed_query(query)
  cos_scores = cosine_similarity([query_embedding], document_embeddings)[0]
  top_result_id = np.argmax(cos_scores)
  return documents[top_result_id]

# %% [markdown]
# ### Try out the function

# %%
new_sentence = 'Tell me about AI'
semantic_search_engine(new_sentence, openai_embed_model)
# Out:
# 'Artificial Intelligence aims to create machines that can think and learn.'

# %%
new_sentence = 'Do you know about the pyramids?'
semantic_search_engine(new_sentence, openai_embed_model)
# Out:
# 'The pyramids of Egypt are historical monuments that have stood for thousands of years.'

# %%
new_sentence = 'How do plants survive?'
semantic_search_engine(new_sentence, openai_embed_model)
# Out:
# 'Photosynthesis is the process by which green plants make food using sunlight.'
